# %% [markdown]
# # Initial Setup

# %%
# !git clone https://github.com/joelpaulehealth/video_surveillance.git
# Out:
# Cloning into 'video_surveillance'...
# remote: Enumerating objects: 81, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 81 (delta 9), reused 78 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (81/81), 1.67 MiB | 21.63 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
# !pip install -r video_surveillance/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 26.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 61.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.2/254.2 kB 17.9 MB/s eta 0:00:00
# ...
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110460 sha256=6c967bc6548f3e2ac068d5d9bc202d824b9d54d909f5beb95c32e9511d799fa0
#   Stored in directory: /root/.cache/pip/wheels/77/bf/4c/b0c3f4798a0166668752312a67118b27a3cd341e13ac0ae6ee
# Successfully built filterpy
# ...

# %% [markdown]
# # Run

# %% [markdown]
# ## DataSets

# %%
#!/bin/bash

# !mkdir -p data
# !cd data

# Download MOT17
# !echo "Downloading MOT17..."
# !wget -c https://motchallenge.net/data/MOT17.zip

# Extract only selected sequences
# !echo "Extracting selected sequences..."
# !unzip MOT17.zip
# !rm MOT17.zip

# !echo "Done!"

# %%
# !zip -r /content/MOT17-04-DPM.zip /content/MOT17/train/MOT17-04-DPM/

# %%
# !wget -c https://www.dropbox.com/sh/75v5ehq4cdg5g5g/AABvnJSwZI7zXb8_myBA0CLHa?dl=0

# %% [markdown]
# ## Generate Videos

# %%
# Convert all training sequences to videos
# !python video_surveillance/tools/preprocess_mot7.py --mot-dir MOT17 --output data/videos --split train

# %% [markdown]
# ## Detect and Track

# %%
# !python3 video_surveillance/run.py --video /content/data/videos/MOT17-09-SDP.mp4 --output output/MOT17-09-SDP.mp4 --device cpu

# %%
# !zip -r /content/output.zip /content/output

# %%
from google.colab import files
files.download('/content/output.zip')
